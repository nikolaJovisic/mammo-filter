# %%
import sys 

sys.path.append('..')

from datasets_shim import *
from batched_dataloader import get_batched_dataloader, BatchEnum
from embedding_inference import EmbeddingInference
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.
# /home/nikola.jovisic.ivi/.local/lib/python3.10/site-packages/_distutils_hack/__init__.py:53: UserWarning: Reliance on distutils from stdlib is deprecated. Users must rely on setuptools to provide the distutils module. Avoid importing distutils or import setuptools first, and avoid setting SETUPTOOLS_USE_DISTUTILS=stdlib. Register concerns at https://github.com/pypa/setuptools/issues/new?template=distutils-deprecation.yml
#   warnings.warn(
# /home/nikola.jovisic.ivi/nj/mammo-filter/experiments/../model/layers/swiglu_ffn.py:43: UserWarning: xFormers is available (SwiGLU)
#   warnings.warn("xFormers is available (SwiGLU)")
# /home/nikola.jovisic.ivi/nj/mammo-filter/experiments/../model/layers/attention.py:27: UserWarning: xFormers is available (Attention)
#   warnings.warn("xFormers is available (Attention)")
# ...

# %%
# pos_train_ds = MammoDataset(DatasetEnum.EMBED, Split.TRAIN, ReturnMode.BREAST_TILES_LABEL, ConvertTo.RGB_TENSOR_IMGNET_NORM, tile_size=(518, 518), labels=[4, 5], resize=518)
# neg_train_ds = MammoDataset(DatasetEnum.EMBED, Split.TRAIN, ReturnMode.BREAST_TILES_LABEL, ConvertTo.RGB_TENSOR_IMGNET_NORM, tile_size=(518, 518), labels=1, resize=518, limit=5*len(pos_train_ds))

# pos_valid_ds = MammoDataset(DatasetEnum.EMBED, Split.VALID, ReturnMode.BREAST_TILES_LABEL, ConvertTo.RGB_TENSOR_IMGNET_NORM, tile_size=(518, 518), labels=[4, 5], resize=518)
# neg_valid_ds = MammoDataset(DatasetEnum.EMBED, Split.VALID, ReturnMode.BREAST_TILES_LABEL, ConvertTo.RGB_TENSOR_IMGNET_NORM, tile_size=(518, 518), labels=1, resize=518, limit=5*len(pos_valid_ds))

# pos_test_ds = MammoDataset(DatasetEnum.EMBED, Split.TEST, ReturnMode.BREAST_TILES_LABEL, ConvertTo.RGB_TENSOR_IMGNET_NORM, tile_size=(518, 518), labels=[4, 5], resize=518)
# neg_test_ds = MammoDataset(DatasetEnum.EMBED, Split.TEST, ReturnMode.BREAST_TILES_LABEL, ConvertTo.RGB_TENSOR_IMGNET_NORM, tile_size=(518, 518), labels=1, resize=518, limit=5*len(pos_test_ds))

# train_ds = UnifiedDataset([pos_train_ds, neg_train_ds])
# valid_ds = UnifiedDataset([pos_valid_ds, neg_valid_ds])
# test_ds = UnifiedDataset([pos_test_ds, neg_test_ds])

# embedding_inference = EmbeddingInference(train_ds, run_id='embed-simple-mama-train')
# embedding_inference.run_images()


# embedding_inference = EmbeddingInference(valid_ds, run_id='embed-simple-mama-valid')
# embedding_inference.run_images()


# embedding_inference = EmbeddingInference(test_ds, run_id='embed-simple-mama-test')
# embedding_inference.run_images()

# %%
for split in [Split.TRAIN, Split.VALID, Split.TEST]:
    datasets = []
    for dataset_enum in [DatasetEnum.CSAW, DatasetEnum.EMBED, DatasetEnum.RSNA, DatasetEnum.VINDR]:
        datasets.append(MammoDataset(dataset_enum, split, ReturnMode.BREAST_TILES_LABEL, ConvertTo.RGB_TENSOR_IMGNET_NORM, tile_size=(518, 518), resize=518))
    dataset = 
    

# count = df[((df['rad_r1'] == 1.0) | (df['rad_r2'] == 1.0)) & (df['rad_recall'] == 0.0)].shape[0]
# count = df[((df['rad_r1'] == 1.0) | (df['rad_r2'] == 1.0)) & (df['rad_recall'] == 0.0)].shape[0]
# print(count)
# Out:
# Dataset csaw initialized with 63584 rows.
# 0
# 0
# 0
# 0
# KeyboardInterrupt

# %%
# for dataset_enum in [DatasetEnum.VINDR]:
#     for split in [Split.TRAIN, Split.VALID, Split.TEST]:
#         for read_window in [True]:
#             windowed_suffix = '-dcm-windowed' if read_window else ''
#             run_id = f'{dataset_enum.value}-simple-{split.value[:-1]}{windowed_suffix}'
            
#             dataset = MammoDataset(dataset_enum, split, ReturnMode.BREAST_TILES_LABEL, ConvertTo.RGB_TENSOR_IMGNET_NORM, tile_size=(518, 518), resize=518, read_window=read_window)
            
#             print(run_id)
            
#             embedding_inference = EmbeddingInference(dataset, run_id=run_id)
#             embedding_inference.run_images()
